# %%
# Install vaderSentiment library
# !pip install pandas vadersentiment

# %%
# Import packages
import pandas as pd
import re
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# Load dataset
df = pd.read_csv('cleaned_gp_comment.csv')

# %%
# Specify comment column 
text_col = 'Comments'
print(f"Using text column: {text_col}")
# Out:
# Using text column: Comments

# %%
# Perform VADER sentiment analysis
analyzer = SentimentIntensityAnalyzer()

def vader_scores(text):
    return analyzer.polarity_scores(str(text))

df['vader_neg'] = df['Comments'].apply(lambda t: vader_scores(t)['neg'])
df['vader_neu'] = df['Comments'].apply(lambda t: vader_scores(t)['neu'])
df['vader_pos'] = df['Comments'].apply(lambda t: vader_scores(t)['pos'])
df['vader_compound'] = df['Comments'].apply(lambda t: vader_scores(t)['compound'])

# %%
# View first few comments with VADER scores
df[['Comments', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound']].head(10)
# Out:
#                                             Comments  vader_neg  vader_neu  \
# 0                          Taste super delicious too        0.0      0.208
# 1                                                Wow        0.0      0.000
# 2  The non-sticky texture of Golden Penny Macaron...        0.0      0.691
# 3                                     Very delicious        0.0      0.200
# 4           After eating Macaroni I sleep very well.        0.0      0.715
# 5                                 Non sticky texture        0.0      1.000
# 6                                     This delicious        0.0      0.213
# 7                                         Delicious!        0.0      0.000
# 8                 That's my favorites than spaghetti        0.0      0.588
# 9                                        My favorite        0.0      0.250
#
#    vader_pos  vader_compound
# 0      0.792          0.8225
# 1      1.000          0.5859
# 2      0.309          0.6166
# 3      0.800          0.6115
# 4      0.285          0.3384
# 5      0.000          0.0000
# 6      0.787          0.5719
# 7      1.000          0.6114
# 8      0.412          0.4215
# 9      0.750          0.4588

# %%
# Statictics of the analyzed comments
df[[ 'vader_compound']].describe()
# Out:
#        vader_compound
# count     1294.000000
# mean         0.326174
# std          0.367310
# min         -0.848100
# 25%          0.000000
# 50%          0.415100
# 75%          0.636900
# max          0.971600

# %%
# Label comments as positive, negative, or neutral
threshold = 0.5

def label_from_compound(c):
    if c >= threshold:
        return 'positive'
    if c <= -threshold:
        return 'negative'
    return 'neutral'

df['vader_label'] = df['vader_compound'].apply(label_from_compound)

# %%
# Save sentiment labels
gp_comments_sl = 'cleaned_gp_comment.csv'
df.to_csv(gp_comments_sl, index=False)

# %%
# View sentiment distribution
print("\nSentiment distribution with threshold 0.5:")
print(df['vader_label'].value_counts())
# Out:
# Sentiment distribution with threshold 0.5:
# vader_label
# neutral     721
# positive    550
# negative     23
# Name: count, dtype: int64

# %%
 # Preview results
df[['Comments', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound', 'vader_label']].head(10)
# Out:
#                                             Comments  vader_neg  vader_neu  \
# 0                          Taste super delicious too        0.0      0.208
# 1                                                Wow        0.0      0.000
# 2  The non-sticky texture of Golden Penny Macaron...        0.0      0.691
# 3                                     Very delicious        0.0      0.200
# 4           After eating Macaroni I sleep very well.        0.0      0.715
# 5                                 Non sticky texture        0.0      1.000
# 6                                     This delicious        0.0      0.213
# 7                                         Delicious!        0.0      0.000
# 8                 That's my favorites than spaghetti        0.0      0.588
# 9                                        My favorite        0.0      0.250
#
#    vader_pos  vader_compound vader_label
# 0      0.792          0.8225    positive
# 1      1.000          0.5859    positive
# 2      0.309          0.6166    positive
# 3      0.800          0.6115    positive
# 4      0.285          0.3384     neutral
# 5      0.000          0.0000     neutral
# 6      0.787          0.5719    positive
# 7      1.000          0.6114    positive
# 8      0.412          0.4215     neutral
# 9      0.750          0.4588     neutral
